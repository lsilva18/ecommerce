# %% [markdown]
# Notebook used for binding external data

# %%
import pandas as pd

# %%
file_path = "./external/amazon_com-amazon_com_product__20210101_20210331_sample.csv"
amazon_2021 = pd.read_csv(file_path)
amazon_2021.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  11097425df1a0b4e3370ba26c302df8c  2021-02-28 10:44:36 +0000
# 1  b5fdae62a293fd8dd7e0eec2fec5b9d9  2021-02-28 08:36:39 +0000
# 2  b109f1429e989c533a1fe7e28ac68518  2021-02-28 09:11:54 +0000
# 3  3c694e4526d13c6f92627007799dae11  2021-02-28 09:02:55 +0000
# 4  8b348a893a3953ebfeae4daab421777e  2021-02-28 06:24:08 +0000
#
#                                              Pageurl     Website  \
# 0  https://www.amazon.com/uxcell-Propellers-Phant...  Amazon.com
# 1  https://www.amazon.com/Holy-Stone-Quadcopter-B...  Amazon.com
# 2  https://www.amazon.com/CGIIGI-Quadcopter-Profe...  Amazon.com
# 3  https://www.amazon.com/Navitech-Protective-Wri...  Amazon.com
# 4  https://www.amazon.com/Cozylady-LED-Strip-Ligh...  Amazon.com
#
#                                                Title  Num Of Reviews  \
# 0  Visit the uxcell Store uxcell RC Propellers 94...               0
# ...

# %%
file_path = "./external/amazon_com-amazon_product_data__20200401_20200630_sample.tsv"
amazon_2020 = pd.read_csv(file_path, sep='\t')
amazon_2020.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  711decb2a3fdcbbe44755afc5af25e2f  2020-05-17 14:24:52 +0000
# 1  443f90af51b4d556fa37aea9b4bfa8ef  2020-05-17 15:33:22 +0000
# 2  11d67e2c4ae95742771a7788008a3cc4  2020-05-17 15:31:57 +0000
# 3  e59801c0a00900acb8db3aabdf6a4859  2020-05-17 15:38:26 +0000
# 4  e28d0551fbf16092efc7cf840fa7d72c  2020-05-17 14:57:47 +0000
#
#    Dataset Origin                        Product Id    Product Barcode  \
# 0             NaN  95495f579545cac053255ae7ce305691                NaN
# 1             NaN  8d523ad2423fd30cb5bf400946d496b1  UPC: 823712247156
# 2             NaN  910b9f10651d9d31744604eed7c11346                NaN
# 3             NaN  8d8db2540550e26f315a422785441fa6                NaN
# 4             NaN  661d79f65d90d69d87c08a7d2927a35f  UPC: 823544494919
#
#   Product Company Type Source  Product Brand Source  \
# 0                  Competitor                   NaN
# ...

# %%
file_path = "./external/walmart_com-walmart_com_product_details__20210101_20210331_sample.csv"
walmart = pd.read_csv(file_path)
walmart.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  3e200df241596109a79b886e77699404  2021-03-22 08:19:25 +0000
# 1  c1f78342b07fb55b0633bef4c0615e27  2021-03-22 08:19:25 +0000
# 2  8b7ef98ebb66612c6603134ffb6e1482  2021-03-22 08:55:24 +0000
# 3  a1d1107302dcc4e34bb9095fc932be78  2021-03-22 08:50:34 +0000
# 4  bb29f162082c216ec682a8336010585d  2021-03-22 08:09:16 +0000
#
#                                              Pageurl      Website  \
# 0  https://www.walmart.com/ip/WiFi-Smart-Curtain-...  walmart.com
# 1  https://www.walmart.com/ip/WiFi-Smart-Curtain-...  walmart.com
# 2  https://www.walmart.com/ip/Spectra-Merchandisi...  walmart.com
# 3  https://www.walmart.com/ip/ANSELL-RD96-T-92-11...  walmart.com
# 4  https://www.walmart.com/ip/Non-slip-Voice-Remo...  walmart.com
#
#                                                Title  Num Of Reviews  \
# 0  Gear Mechanical WiFi Smart Curtain Switch Touc...               0
# ...
